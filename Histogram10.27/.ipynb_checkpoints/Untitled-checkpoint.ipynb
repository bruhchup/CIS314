# %% [markdown]
# # Histogram

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
mean = 10
std = 3
rng = np.random.default_rng()

f = rng.normal(mean,std,1000)

for i in f:
    i + 0.5
    int(i)

# %%
np.histogram(f, bins = 20)
# Out:
# (array([  3,   5,   5,  15,  23,  39,  63,  77,  92, 108, 128, 120, 111,
#          80,  52,  36,  18,  15,   8,   2], dtype=int64),
#  array([ 0.61196924,  1.52040022,  2.4288312 ,  3.33726218,  4.24569316,
#          5.15412414,  6.06255512,  6.97098611,  7.87941709,  8.78784807,
#          9.69627905, 10.60471003, 11.51314101, 12.42157199, 13.33000298,
#         14.23843396, 15.14686494, 16.05529592, 16.9637269 , 17.87215788,
#         18.78058887]))

# %%
plt.hist(f)
# Out:
# (array([  8.,  20.,  62., 140., 200., 248., 191.,  88.,  33.,  10.]),
#  array([ 0.61196924,  2.4288312 ,  4.24569316,  6.06255512,  7.87941709,
#          9.69627905, 11.51314101, 13.33000298, 15.14686494, 16.9637269 ,
#         18.78058887]),
#  <BarContainer object of 10 artists>)
